# %% [markdown]
# # Automate Chess Gameplay
#
# In this notebook we illustrate the gameplay of Automate Chess

# %%
import sys
sys.path.insert(0, "../utils")
from IPython.core import display as ICD

# %%
import chess
import chess.engine
import constants
import placements
import random

# %%
def setup_random_game():
    print("White's placements")
    comb = random.choice(constants.COMBINATIONS)
    print(comb)
    print(placements.check_feasible_comb(*comb))
    white_mini_board = placements.generate_placement(*comb)

    print("Black's placements")
    comb = random.choice(constants.COMBINATIONS)
    print(comb)
    print(placements.check_feasible_comb(*comb))
    black_mini_board = placements.generate_placement(*comb)

    board = placements.generate_board(white_mini_board, black_mini_board)
    placements.print_full_board(board)
    fen = placements.generate_fen(board)
    print(fen)
    board = chess.Board(fen)
    return board

# %%
pondertime = 1.0
maxmoves = 200
dictsidetomove = {True:'white',False:'black'}
notationdict = {True:'.', False:'...'}

# %%
board = setup_random_game()
board
# Out:
# White's placements
# [7, 2, 5, 0, 1]
# True
# ['P', '-', '-', 'P', 'P', '-', '-', 'P']
# ['B', 'B', 'B', 'K', 'P', 'N', 'P', 'P']
# ['-', 'B', '-', 'N', 'Q', 'B', '-', '-']
#
# Black's placements
# [6, 4, 2, 1, 1]
# True
# ['-', 'P', '-', '-', '-', '-', '-', '-']
# ['P', '-', 'P', 'N', 'P', 'P', 'Q', 'P']
# ['-', 'N', 'R', 'N', 'B', 'K', 'B', 'N']
#
# ['n', 'b', 'k', 'b', 'n', 'r', 'n', '-']
# ['p', 'q', 'p', 'p', 'n', 'p', '-', 'p']
# ['-', '-', '-', '-', '-', '-', 'p', '-']
# ['-', '-', '-', '-', '-', '-', '-', '-']
# ['-', '-', '-', '-', '-', '-', '-', '-']
# ['P', '-', '-', 'P', 'P', '-', '-', 'P']
# ['B', 'B', 'B', 'K', 'P', 'N', 'P', 'P']
# ['-', 'B', '-', 'N', 'Q', 'B', '-', '-']
#
# nbkbnrn1/pqppnp1p/6p1/8/8/P2PP2P/BBBKPNPP/1B1NQB2 w - - 0 1
# Board('nbkbnrn1/pqppnp1p/6p1/8/8/P2PP2P/BBBKPNPP/1B1NQB2 w - - 0 1')

# %%
engine = chess.engine.SimpleEngine.popen_uci(constants.SF_PATH)

# %%
info = engine.analyse(board, chess.engine.Limit(time=0.1))
print(info)
print("Score:", info["score"])
# Out:
# {'string': 'NNUE evaluation using nn-62ef826d1a6d.nnue enabled', 'depth': 14, 'seldepth': 17, 'multipv': 1, 'score': PovScore(Cp(-38), WHITE), 'nodes': 87657, 'nps': 859382, 'tbhits': 0, 'time': 0.102, 'pv': [Move.from_uci('d2c1'), Move.from_uci('c7c6')]}
# Score: PovScore(Cp(-38), WHITE)

# %%
while not board.is_game_over() and board.fullmove_number<=maxmoves:
    result = engine.play(board,chess.engine.Limit(time=pondertime))
    print(dictsidetomove[board.turn]+' played '+str(board.fullmove_number)+notationdict[board.turn]+str(board.san(result.move)))
    board.push(result.move)
    ICD.display(board)
print(board)
print('Final position FEN: ',board.fen())
print('-----')
# Out:
# white played 1.Kc1
# Board('nbkbnrn1/pqppnp1p/6p1/8/8/P2PP2P/BBB1PNPP/1BKNQB2 b - - 1 1')
# black played 1...c6
# Board('nbkbnrn1/pq1pnp1p/2p3p1/8/8/P2PP2P/BBB1PNPP/1BKNQB2 w - - 0 2')
# white played 2.g3
# Board('nbkbnrn1/pq1pnp1p/2p3p1/8/8/P2PP1PP/BBB1PN1P/1BKNQB2 b - - 0 2')
# black played 2...Ngf6
# Board('nbkbnr2/pq1pnp1p/2p2np1/8/8/P2PP1PP/BBB1PN1P/1BKNQB2 w - - 1 3')
# white played 3.Bg2
# Board('nbkbnr2/pq1pnp1p/2p2np1/8/8/P2PP1PP/BBB1PNBP/1BKNQ3 b - - 2 3')
# black played 3...Bbc7
# Board('n1kbnr2/pqbpnp1p/2p2np1/8/8/P2PP1PP/BBB1PNBP/1BKNQ3 w - - 3 4')
# white played 4.e4
# Board('n1kbnr2/pqbpnp1p/2p2np1/8/4P3/P2P2PP/BBB1PNBP/1BKNQ3 b - - 0 4')
# black played 4...Ba5
# Board('n1kbnr2/pq1pnp1p/2p2np1/b7/4P3/P2P2PP/BBB1PNBP/1BKNQ3 w - - 1 5')
# white played 5.Qf1
# Board('n1kbnr2/pq1pnp1p/2p2np1/b7/4P3/P2P2PP/BBB1PNBP/1BKN1Q2 b - - 2 5')
# black played 5...d5
# Board('n1kbnr2/pq2np1p/2p2np1/b2p4/4P3/P2P2PP/BBB1PNBP/1BKN1Q2 w - - 0 6')
# white played 6.exd5
# Board('n1kbnr2/pq2np1p/2p2np1/b2P4/8/P2P2PP/BBB1PNBP/1BKN1Q2 b - - 0 6')
# black played 6...cxd5
# Board('n1kbnr2/pq2np1p/5np1/b2p4/8/P2P2PP/BBB1PNBP/1BKN1Q2 w - - 0 7')
# white played 7.e4
# Board('n1kbnr2/pq2np1p/5np1/b2p4/4P3/P2P2PP/BBB2NBP/1BKN1Q2 b - - 0 7')
# black played 7...Nac7
# Board('2kbnr2/pqn1np1p/5np1/b2p4/4P3/P2P2PP/BBB2NBP/1BKN1Q2 w - - 1 8')
# white played 8.Ba4
# Board('2kbnr2/pqn1np1p/5np1/b2p4/B3P3/P2P2PP/BB3NBP/1BKN1Q2 b - - 2 8')
# black played 8...Qb6
# Board('2kbnr2/p1n1np1p/1q3np1/b2p4/B3P3/P2P2PP/BB3NBP/1BKN1Q2 w - - 3 9')
# white played 9.Bbc2
# Board('2kbnr2/p1n1np1p/1q3np1/b2p4/B3P3/P2P2PP/BBB2NBP/2KN1Q2 b - - 4 9')
# black played 9...Nc6
# Board('2kbnr2/p1n2p1p/1qn2np1/b2p4/B3P3/P2P2PP/BBB2NBP/2KN1Q2 w - - 5 10')
# white played 10.e5
# Board('2kbnr2/p1n2p1p/1qn2np1/b2pP3/B7/P2P2PP/BBB2NBP/2KN1Q2 b - - 0 10')
# black played 10...Nd7
# Board('2kbnr2/p1nn1p1p/1qn3p1/b2pP3/B7/P2P2PP/BBB2NBP/2KN1Q2 w - - 1 11')
# white played 11.Qe2
# Board('2kbnr2/p1nn1p1p/1qn3p1/b2pP3/B7/P2P2PP/BBB1QNBP/2KN4 b - - 2 11')
# black played 11...f5
# Board('2kbnr2/p1nn3p/1qn3p1/b2pPp2/B7/P2P2PP/BBB1QNBP/2KN4 w - f6 0 12')
# white played 12.Bxc6
# Board('2kbnr2/p1nn3p/1qB3p1/b2pPp2/8/P2P2PP/BBB1QNBP/2KN4 b - - 0 12')
# black played 12...Qxc6
# Board('2kbnr2/p1nn3p/2q3p1/b2pPp2/8/P2P2PP/BBB1QNBP/2KN4 w - - 0 13')
# white played 13.Kb1
# Board('2kbnr2/p1nn3p/2q3p1/b2pPp2/8/P2P2PP/BBB1QNBP/1K1N4 b - - 1 13')
# black played 13...Nb6
# Board('2kbnr2/p1n4p/1nq3p1/b2pPp2/8/P2P2PP/BBB1QNBP/1K1N4 w - - 2 14')
# white played 14.Bcb3
# Board('2kbnr2/p1n4p/1nq3p1/b2pPp2/8/PB1P2PP/BB2QNBP/1K1N4 b - - 3 14')
# black played 14...Bg5
# Board('2k1nr2/p1n4p/1nq3p1/b2pPpb1/8/PB1P2PP/BB2QNBP/1K1N4 w - - 4 15')
# white played 15.Qc2
# Board('2k1nr2/p1n4p/1nq3p1/b2pPpb1/8/PB1P2PP/BBQ2NBP/1K1N4 b - - 5 15')
# black played 15...Qxc2+
# Board('2k1nr2/p1n4p/1n4p1/b2pPpb1/8/PB1P2PP/BBq2NBP/1K1N4 w - - 0 16')
# white played 16.Kxc2
# Board('2k1nr2/p1n4p/1n4p1/b2pPpb1/8/PB1P2PP/BBK2NBP/3N4 b - - 0 16')
# black played 16...Ng7
# Board('2k2r2/p1n3np/1n4p1/b2pPpb1/8/PB1P2PP/BBK2NBP/3N4 w - - 1 17')
# white played 17.h4
# Board('2k2r2/p1n3np/1n4p1/b2pPpb1/7P/PB1P2P1/BBK2NBP/3N4 b - - 0 17')
# black played 17...Bh6
# Board('2k2r2/p1n3np/1n4pb/b2pPp2/7P/PB1P2P1/BBK2NBP/3N4 w - - 1 18')
# white played 18.Bgxd5
# Board('2k2r2/p1n3np/1n4pb/b2BPp2/7P/PB1P2P1/BBK2N1P/3N4 b - - 0 18')
# black played 18...Nbxd5
# Board('2k2r2/p1n3np/6pb/b2nPp2/7P/PB1P2P1/BBK2N1P/3N4 w - - 0 19')
# white played 19.Bxd5
# Board('2k2r2/p1n3np/6pb/b2BPp2/7P/P2P2P1/BBK2N1P/3N4 b - - 0 19')
# black played 19...Nxd5
# Board('2k2r2/p5np/6pb/b2nPp2/7P/P2P2P1/BBK2N1P/3N4 w - - 0 20')
# white played 20.Bxd5
# Board('2k2r2/p5np/6pb/b2BPp2/7P/P2P2P1/1BK2N1P/3N4 b - - 0 20')
# black played 20...Bb6
# Board('2k2r2/p5np/1b4pb/3BPp2/7P/P2P2P1/1BK2N1P/3N4 w - - 1 21')
# white played 21.a4
# Board('2k2r2/p5np/1b4pb/3BPp2/P6P/3P2P1/1BK2N1P/3N4 b - - 0 21')
# black played 21...Re8
# Board('2k1r3/p5np/1b4pb/3BPp2/P6P/3P2P1/1BK2N1P/3N4 w - - 1 22')
# white played 22.Bc3
# Board('2k1r3/p5np/1b4pb/3BPp2/P6P/2BP2P1/2K2N1P/3N4 b - - 2 22')
# black played 22...Rd8
# Board('2kr4/p5np/1b4pb/3BPp2/P6P/2BP2P1/2K2N1P/3N4 w - - 3 23')
# white played 23.Bc4
# Board('2kr4/p5np/1b4pb/4Pp2/P1B4P/2BP2P1/2K2N1P/3N4 b - - 4 23')
# black played 23...Kb7
# Board('3r4/pk4np/1b4pb/4Pp2/P1B4P/2BP2P1/2K2N1P/3N4 w - - 5 24')
# white played 24.Nh3
# Board('3r4/pk4np/1b4pb/4Pp2/P1B4P/2BP2PN/2K4P/3N4 b - - 6 24')
# black played 24...Ne8
# Board('3rn3/pk5p/1b4pb/4Pp2/P1B4P/2BP2PN/2K4P/3N4 w - - 7 25')
# white played 25.Nf4
# Board('3rn3/pk5p/1b4pb/4Pp2/P1B2N1P/2BP2P1/2K4P/3N4 b - - 8 25')
# black played 25...Bxf4
# Board('3rn3/pk5p/1b4p1/4Pp2/P1B2b1P/2BP2P1/2K4P/3N4 w - - 0 26')
# white played 26.gxf4
# Board('3rn3/pk5p/1b4p1/4Pp2/P1B2P1P/2BP4/2K4P/3N4 b - - 0 26')
# black played 26...Nc7
# Board('3r4/pkn4p/1b4p1/4Pp2/P1B2P1P/2BP4/2K4P/3N4 w - - 1 27')
# white played 27.Bd2
# Board('3r4/pkn4p/1b4p1/4Pp2/P1B2P1P/3P4/2KB3P/3N4 b - - 2 27')
# black played 27...Nd5
# Board('3r4/pk5p/1b4p1/3nPp2/P1B2P1P/3P4/2KB3P/3N4 w - - 3 28')
# white played 28.Kb3
# Board('3r4/pk5p/1b4p1/3nPp2/P1B2P1P/1K1P4/3B3P/3N4 b - - 4 28')
# black played 28...Bc5
# Board('3r4/pk5p/6p1/2bnPp2/P1B2P1P/1K1P4/3B3P/3N4 w - - 5 29')
# white played 29.Ba5
# Board('3r4/pk5p/6p1/B1bnPp2/P1B2P1P/1K1P4/7P/3N4 b - - 6 29')
# black played 29...Bb6
# Board('3r4/pk5p/1b4p1/B2nPp2/P1B2P1P/1K1P4/7P/3N4 w - - 7 30')
# white played 30.Bd2
# Board('3r4/pk5p/1b4p1/3nPp2/P1B2P1P/1K1P4/3B3P/3N4 b - - 8 30')
# black played 30...Bg1
# Board('3r4/pk5p/6p1/3nPp2/P1B2P1P/1K1P4/3B3P/3N2b1 w - - 9 31')
# white played 31.Nc3
# Board('3r4/pk5p/6p1/3nPp2/P1B2P1P/1KNP4/3B3P/6b1 b - - 10 31')
# black played 31...Nb6
# Board('3r4/pk5p/1n4p1/4Pp2/P1B2P1P/1KNP4/3B3P/6b1 w - - 11 32')
# white played 32.Nb5
# Board('3r4/pk5p/1n4p1/1N2Pp2/P1B2P1P/1K1P4/3B3P/6b1 b - - 12 32')
# black played 32...Bxh2
# Board('3r4/pk5p/1n4p1/1N2Pp2/P1B2P1P/1K1P4/3B3b/8 w - - 0 33')
# white played 33.e6
# Board('3r4/pk5p/1n2P1p1/1N3p2/P1B2P1P/1K1P4/3B3b/8 b - - 0 33')
# black played 33...Rb8
# Board('1r6/pk5p/1n2P1p1/1N3p2/P1B2P1P/1K1P4/3B3b/8 w - - 1 34')
# white played 34.d4
# Board('1r6/pk5p/1n2P1p1/1N3p2/P1BP1P1P/1K6/3B3b/8 b - - 0 34')
# black played 34...a6
# Board('1r6/1k5p/pn2P1p1/1N3p2/P1BP1P1P/1K6/3B3b/8 w - - 0 35')
# white played 35.Nd6+
# Board('1r6/1k5p/pn1NP1p1/5p2/P1BP1P1P/1K6/3B3b/8 b - - 1 35')
# black played 35...Kc6
# Board('1r6/7p/pnkNP1p1/5p2/P1BP1P1P/1K6/3B3b/8 w - - 2 36')
# white played 36.Nf7
# Board('1r6/5N1p/pnk1P1p1/5p2/P1BP1P1P/1K6/3B3b/8 b - - 3 36')
# black played 36...Nd5+
# Board('1r6/5N1p/p1k1P1p1/3n1p2/P1BP1P1P/1K6/3B3b/8 w - - 4 37')
# white played 37.Kc2
# Board('1r6/5N1p/p1k1P1p1/3n1p2/P1BP1P1P/8/2KB3b/8 b - - 5 37')
# black played 37...Bg3
# Board('1r6/5N1p/p1k1P1p1/3n1p2/P1BP1P1P/6b1/2KB4/8 w - - 6 38')
# white played 38.Ne5+
# Board('1r6/7p/p1k1P1p1/3nNp2/P1BP1P1P/6b1/2KB4/8 b - - 7 38')
# black played 38...Kd6
# Board('1r6/7p/p2kP1p1/3nNp2/P1BP1P1P/6b1/2KB4/8 w - - 8 39')
# white played 39.Nf7+
# Board('1r6/5N1p/p2kP1p1/3n1p2/P1BP1P1P/6b1/2KB4/8 b - - 9 39')
# black played 39...Kxe6
# Board('1r6/5N1p/p3k1p1/3n1p2/P1BP1P1P/6b1/2KB4/8 w - - 0 40')
# white played 40.Ng5+
# Board('1r6/7p/p3k1p1/3n1pN1/P1BP1P1P/6b1/2KB4/8 b - - 1 40')
# black played 40...Kd6
# Board('1r6/7p/p2k2p1/3n1pN1/P1BP1P1P/6b1/2KB4/8 w - - 2 41')
# white played 41.Nf7+
# Board('1r6/5N1p/p2k2p1/3n1p2/P1BP1P1P/6b1/2KB4/8 b - - 3 41')
# black played 41...Kc6
# Board('1r6/5N1p/p1k3p1/3n1p2/P1BP1P1P/6b1/2KB4/8 w - - 4 42')
# white played 42.Ne5+
# Board('1r6/7p/p1k3p1/3nNp2/P1BP1P1P/6b1/2KB4/8 b - - 5 42')
# black played 42...Kd6
# Board('1r6/7p/p2k2p1/3nNp2/P1BP1P1P/6b1/2KB4/8 w - - 6 43')
# white played 43.Nf7+
# Board('1r6/5N1p/p2k2p1/3n1p2/P1BP1P1P/6b1/2KB4/8 b - - 7 43')
# black played 43...Kc6
# Board('1r6/5N1p/p1k3p1/3n1p2/P1BP1P1P/6b1/2KB4/8 w - - 8 44')
# white played 44.Ne5+
# Board('1r6/7p/p1k3p1/3nNp2/P1BP1P1P/6b1/2KB4/8 b - - 9 44')
# black played 44...Kd6
# Board('1r6/7p/p2k2p1/3nNp2/P1BP1P1P/6b1/2KB4/8 w - - 10 45')
# white played 45.Nf7+
# Board('1r6/5N1p/p2k2p1/3n1p2/P1BP1P1P/6b1/2KB4/8 b - - 11 45')
# black played 45...Kc6
# Board('1r6/5N1p/p1k3p1/3n1p2/P1BP1P1P/6b1/2KB4/8 w - - 12 46')
# white played 46.Ne5+
# Board('1r6/7p/p1k3p1/3nNp2/P1BP1P1P/6b1/2KB4/8 b - - 13 46')
# black played 46...Kd6
# Board('1r6/7p/p2k2p1/3nNp2/P1BP1P1P/6b1/2KB4/8 w - - 14 47')
# white played 47.Nf7+
# Board('1r6/5N1p/p2k2p1/3n1p2/P1BP1P1P/6b1/2KB4/8 b - - 15 47')
# black played 47...Kc6
# Board('1r6/5N1p/p1k3p1/3n1p2/P1BP1P1P/6b1/2KB4/8 w - - 16 48')
# white played 48.Ne5+
# Board('1r6/7p/p1k3p1/3nNp2/P1BP1P1P/6b1/2KB4/8 b - - 17 48')
# black played 48...Kd6
# Board('1r6/7p/p2k2p1/3nNp2/P1BP1P1P/6b1/2KB4/8 w - - 18 49')
# white played 49.Nf7+
# Board('1r6/5N1p/p2k2p1/3n1p2/P1BP1P1P/6b1/2KB4/8 b - - 19 49')
# . r . . . . . .
# . . . . . N . p
# p . . k . . p .
# . . . n . p . .
# P . B P . P . P
# . . . . . . b .
# . . K B . . . .
# . . . . . . . .
# Final position FEN:  1r6/5N1p/p2k2p1/3n1p2/P1BP1P1P/6b1/2KB4/8 b - - 19 49
# -----

# %% [markdown]
# Game ended as a draw by repetition

# %%
info = engine.analyse(board, chess.engine.Limit(time=0.1))
print(info)
print("Score:", info["score"])
# Out:
# {'string': 'NNUE evaluation using nn-62ef826d1a6d.nnue enabled', 'depth': 48, 'seldepth': 2, 'multipv': 1, 'score': PovScore(Cp(0), BLACK), 'nodes': 87855, 'nps': 869851, 'tbhits': 0, 'time': 0.101, 'pv': [Move.from_uci('d6c6')]}
# Score: PovScore(Cp(0), BLACK)
